# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharraja/cr/blob/main/cr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def caesar_encrypt(text, shift):

    result = ""
    for c in text:
        if c.isupper():
            result += chr((ord(c) - ord('A') + shift) % 26 + ord('A'))
        elif c.islower():
            result += chr((ord(c) - ord('a') + shift) % 26 + ord('a'))
        else:
            result += c
    return result


def caesar_decrypt(text, shift):

    result = ""
    for c in text:
        if c.isupper():
            result += chr((ord(c) - ord('A') - shift + 26) % 26 + ord('A'))
        elif c.islower():
            result += chr((ord(c) - ord('a') - shift + 26) % 26 + ord('a'))
        else:
            result += c
    return result


def main():

    print("Caesar Cipher \n")


    text = input("Enter plaintext: ")
    shift = int(input("Enter shift value: "))


    encrypted = caesar_encrypt(text, shift)
    print(f"\nOriginal text:  {text}")
    print(f"Encrypted text: {encrypted}")


    decrypted = caesar_decrypt(encrypted, shift)
    print(f"Decrypted text: {decrypted}")


    if text == decrypted:
        print("\n Encryption and decryption successful!")
    else:
        print("\n Error in encryption/decryption")


if __name__ == "__main__":
    main()
# Out:
# Caesar Cipher
#
# Enter plaintext: abxyz
# Enter shift value: 3
#
# Original text:  abxyz
# Encrypted text: deabc
# Decrypted text: abxyz
#
#  Encryption and decryption successful!
